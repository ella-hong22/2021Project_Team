# %%
import pandas as pd

#파일 불러오기
kid_add = pd.read_csv('D:/Ella/project/seoul_놀이터(동별).csv' )
kid_add.head(10)
# Out:
#                        place     type                             address  \
# 0         삼성서울병원2어린이집 실내놀이시설     어린이집  서울특별시 강남구 양재대로55길 12 (일원동, 수서아파트).
# 1        서울학동초등학교 병설유치원 놀이시설      유치원  서울특별시 강남구 선릉로115길 42 (논현동)학동초병설유치원
# 2   디에이치 포레센트 어린이놀이터(103동 옆)     주택단지          서울특별시 강남구 개포로110길 34 (일원동)
# 3            네오플강남어린이집 실외놀이터     어린이집         서울특별시 강남구 강남대로110길 36 (역삼동)
# 4                   캘리클럽키즈카페  놀이제공영업소         서울특별시 강남구 선릉로 832 (청담동)지하2층
# 5               강남드림빌 어린이놀이터   아동복지시설         서울특별시 강남구 양재대로 344-27 (개포동)
# 6  개포래미안포레스트 유아놀이터2(보육시설.옥상)     주택단지              서울특별시 강남구 언주로 21 (개포동)
# 7    개포래미안포레스트 유아놀이터1(124동뒤)     주택단지              서울특별시 강남구 언주로 21 (개포동)
# 8    개포래미안포레스트 어린이놀이터6(129동)     주택단지              서울특별시 강남구 언주로 21 (개포동)
# 9    개포래미안포레스트 어린이놀이터5(123동)     주택단지              서울특별시 강남구 언주로 21 (개포동)
#
#   시군구명   동명
# 0  강남구  일원동
# 1  강남구  논현동
# 2  강남구  일원동
# 3  강남구  역삼동
# 4  강남구  청담동
# 5  강남구  개포동
# 6  강남구  개포동
# 7  강남구  개포동
# 8  강남구  개포동
# 9  강남구  개포동

# %%
#길이가 4이상인 동명을 추출
words= []
for name in dong :
    if len(name) > 4:
        words.append(name)
        

words
# Out:
# ['하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '상왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동',
#  '하왕십리동']

# %%
#행정동 분류(숫자제거)

names = ['금호동1가','금호동4가','금호동동','금호동','동소문동5가','삼선동2가','삼성']
list = []
for name in names:
    a= re.compile('[0-9]+').sub("", name[:4])
    list.append(a)
list
# Out:
# ['금호동', '금호동', '금호동동', '금호동', '동소문동', '삼선동', '삼성']

# %%
dong = kid_add['동명']
dong
# Out:
# 0        일원동
# 1        논현동
# 2        일원동
# 3        역삼동
# 4        청담동
#         ...
# 10047    상봉동
# 10048    중화동
# 10049    상봉동
# 10050    중화동
# 10051    중화동
# Name: 동명, Length: 10052, dtype: object

# %%
#정규식표현 
#숫자포함 글자를 삭제하고 글자만 가져오기 (금호동4가 -> 금호동) 변화
#re.sub('apple|orange', 'fruit', 'apple box orange tree')    # apple 또는 orange를 fruit로 바꿈
# 'fruit box fruit tree'

list = []
for name in dong:
    a= re.compile('[0-9]+').sub("", name[:4])
    list.append(a)
list
# Out:
# ['일원동',
#  '논현동',
#  '일원동',
#  '역삼동',
#  '청담동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '율현동',
#  '대치동',
#  '개포동',
#  '도곡동',
#  '일원동',
#  '역삼동',
#  '논현동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '도곡동',
#  '대치동',
#  '삼성동',
#  '삼성동',
#  '개포동',
#  '도곡동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '일원동',
#  '일원동',
#  '일원동',
#  '자곡동',
#  '삼성동',
#  '삼성동',
#  '삼성동',
#  '도곡동',
#  '삼성동',
#  '수서동',
#  '청담동',
#  '청담동',
#  '대치동',
#  '일원동',
#  '율현동',
#  '역삼동',
#  '청담동',
#  '신사동',
#  '개포동',
#  '개포동',
#  '대치동',
#  '자곡동',
#  '수서동',
#  '수서동',
#  '역삼동',
#  '역삼동',
#  '율현동',
#  '도곡동',
#  '도곡동',
#  '세곡동',
#  '도곡동',
#  '일원동',
#  '대치동',
#  '대치동',
#  '도곡동',
#  '수서동',
#  '자곡동',
#  '역삼동',
#  '신사동',
#  '대치동',
#  '대치동',
#  '대치동',
#  '율현동',
#  '율현동',
#  '율현동',
#  '율현동',
#  '율현동',
#  '수서동',
#  '자곡동',
#  '청담동',
#  '자곡동',
#  '자곡동',
#  '청담동',
#  '도곡동',
#  '역삼동',
#  '청담동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '일원동',
# ...

# %%
#추출된 최종 동명 dataframe에 입력
kid_add['동명']= list
kid_add.head()
# Out:
#                       place     type                             address 시군구명  \
# 0        삼성서울병원2어린이집 실내놀이시설     어린이집  서울특별시 강남구 양재대로55길 12 (일원동, 수서아파트).  강남구
# 1       서울학동초등학교 병설유치원 놀이시설      유치원  서울특별시 강남구 선릉로115길 42 (논현동)학동초병설유치원  강남구
# 2  디에이치 포레센트 어린이놀이터(103동 옆)     주택단지          서울특별시 강남구 개포로110길 34 (일원동)  강남구
# 3           네오플강남어린이집 실외놀이터     어린이집         서울특별시 강남구 강남대로110길 36 (역삼동)  강남구
# 4                  캘리클럽키즈카페  놀이제공영업소         서울특별시 강남구 선릉로 832 (청담동)지하2층  강남구
#
#     동명
# 0  일원동
# 1  논현동
# 2  일원동
# 3  역삼동
# 4  청담동

# %%
#동명중 다섯글자 이상이 단어의 경우, 4글자로 쪼개졌기 때문에, 바꿔줘야 한다. 
names = kid_add['동명']

words= []
for word in names : 
    if word == '상왕십리':
        a= word.replace('상왕십리','상왕십리동')
        words.append(a)
    elif word =='하왕십리':
        b= word.replace('하왕십리','하왕십리동')
        words.append(b)
        
    else :
        words.append(word)
    
words
# Out:
# ['일원동',
#  '논현동',
#  '일원동',
#  '역삼동',
#  '청담동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '율현동',
#  '대치동',
#  '개포동',
#  '도곡동',
#  '일원동',
#  '역삼동',
#  '논현동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '도곡동',
#  '대치동',
#  '삼성동',
#  '삼성동',
#  '개포동',
#  '도곡동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '개포동',
#  '일원동',
#  '일원동',
#  '일원동',
#  '자곡동',
#  '삼성동',
#  '삼성동',
#  '삼성동',
#  '도곡동',
#  '삼성동',
#  '수서동',
#  '청담동',
#  '청담동',
#  '대치동',
#  '일원동',
#  '율현동',
#  '역삼동',
#  '청담동',
#  '신사동',
#  '개포동',
#  '개포동',
#  '대치동',
#  '자곡동',
#  '수서동',
#  '수서동',
#  '역삼동',
#  '역삼동',
#  '율현동',
#  '도곡동',
#  '도곡동',
#  '세곡동',
#  '도곡동',
#  '일원동',
#  '대치동',
#  '대치동',
#  '도곡동',
#  '수서동',
#  '자곡동',
#  '역삼동',
#  '신사동',
#  '대치동',
#  '대치동',
#  '대치동',
#  '율현동',
#  '율현동',
#  '율현동',
#  '율현동',
#  '율현동',
#  '수서동',
#  '자곡동',
#  '청담동',
#  '자곡동',
#  '자곡동',
#  '청담동',
#  '도곡동',
#  '역삼동',
#  '청담동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '자곡동',
#  '일원동',
# ...

# %%
#칼럼 내용 변경 
kid_add['동명']= words

# %%
#저장하기
kid_add.to_csv('D:/Ella/project/seoul_놀이터(동별)_final.csv', index = False)
# kid_add.to_excel('D:/Ella/project/seoul_놀이터(동별)_final.xlsx')

# %%
names = ['금호동1가','금호동4가','금호동동','금호동','동소문동5가','삼선동2가']

#숫자 뒤에 글자를 삭제하고 글자만 가져오기 (연습)

list = []
for name in names:
    a= re.compile('[0-9]+').sub("", name[:4])
    list.append(a)
list
# Out:
# ['금호동', '금호동', '금호동동', '금호동', '동소문동', '삼선동']

# %%
df= pd.read_csv('D:/Ella/project/seoul_놀이터(동별)_final.csv', )

#강남구의 동명 그룹으로 나누기 
gangnam = df[df['시군구명']=='영등포구']
gangnam.groupby('동명')['address'].count()
# Out:
# 동명
# 당산동      64
# 대림동      50
# 도림동      15
# 문래동      48
# 신길동     108
# 양평동      48
# 여의도동     59
# 영등포동     44
# Name: address, dtype: int64

# %%
df.columns
# Out:
# Index(['place', 'type', 'address', '시군구명', '동명'], dtype='object')

# %%
#type을 유료 시설과 무료 시설로 구분 

df.info()
df_dup = df.drop_duplicates()
df = df_dup
df.info()

df.to_csv('D:/Ella/project/seoul_놀이터(동별)_final.csv', index= False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10050 entries, 0 to 10051
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   place    10050 non-null  object
#  1   type     10050 non-null  object
#  2   address  10050 non-null  object
#  3   시군구명     10050 non-null  object
#  4   동명       10050 non-null  object
# dtypes: object(5)
# memory usage: 471.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10050 entries, 0 to 10051
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   place    10050 non-null  object
#  1   type     10050 non-null  object
#  2   address  10050 non-null  object
#  3   시군구명     10050 non-null  object
#  4   동명       10050 non-null  object
# dtypes: object(5)
# memory usage: 471.1+ KB

# %%
result= pd.read_csv('D:/Ella/project/seoul_놀이터(동별)_final.csv' )
result.head()
# Out:
#                       place     type                             address 시군구명  \
# 0        삼성서울병원2어린이집 실내놀이시설     어린이집  서울특별시 강남구 양재대로55길 12 (일원동, 수서아파트).  강남구
# 1       서울학동초등학교 병설유치원 놀이시설      유치원  서울특별시 강남구 선릉로115길 42 (논현동)학동초병설유치원  강남구
# 2  디에이치 포레센트 어린이놀이터(103동 옆)     주택단지          서울특별시 강남구 개포로110길 34 (일원동)  강남구
# 3           네오플강남어린이집 실외놀이터     어린이집         서울특별시 강남구 강남대로110길 36 (역삼동)  강남구
# 4                  캘리클럽키즈카페  놀이제공영업소         서울특별시 강남구 선릉로 832 (청담동)지하2층  강남구
#
#     동명
# 0  일원동
# 1  논현동
# 2  일원동
# 3  역삼동
# 4  청담동

# %%
result[result['동명']=='청파동2가']
# Out:
# Empty DataFrame
# Columns: [place, type, address, 시군구명, 동명]
# Index: []

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10050 entries, 0 to 10049
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   place    10050 non-null  object
#  1   type     10050 non-null  object
#  2   address  10050 non-null  object
#  3   시군구명     10050 non-null  object
#  4   동명       10050 non-null  object
# dtypes: object(5)
# memory usage: 392.7+ KB

# %%
result.groupby('type').count()
# Out:
#          place  address  시군구명    동명
# type
# 공공도서관        4        4     4     4
# 놀이제공영업소    109      109   109   109
# 대규모점포       17       17    17    17
# 도시공원      1589     1589  1589  1589
# 목욕장업소       13       13    13    13
# 박물관          3        3     3     3
# 식품접객업소      60       60    60    60
# 아동복지시설      54       54    54    54
# 어린이집      1011     1011  1011  1011
# 유치원        534      534   534   534
# 의료기관         5        5     5     5
# 종교시설        46       46    46    46
# 주상복합        39       39    39    39
# 주택단지      5883     5883  5883  5883
# 하천          14       14    14    14
# 학교         639      639   639   639
# 학원          30       30    30    30

# %%
free_zones =  ['공공도서관','도시공원', '박물관', '아동복지시설', '어린이집','유치원', '주상복합','주택단지',
             '하천','학교']

pay_zones = ['놀이제공영업소','대규모점포','목욕장업소', '식품접객업소', '의료기관','종교시설','학원']

# %%
#특정 데이터를 따로 분리해서 데이터 프레임 붙이기

for place in free_zones : 
    a = result[result['type'] == place]
    free_places.append(a)  
#     free_places.append(b)
    
free_places.info()

# %%
free_places.duplicated()
#중복값 처리
free_places_dup = free_places.drop_duplicates()
free_places_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9770 entries, 20 to 9039
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   place    9770 non-null   object
#  1   type     9770 non-null   object
#  2   address  9770 non-null   object
#  3   시군구명     9770 non-null   object
#  4   동명       9770 non-null   object
# dtypes: object(5)
# memory usage: 458.0+ KB

# %%
dong = free_places_dup['동명']

# %%
list = []
for name in dong:
    a= re.compile('[0-9]+').sub("", name[:4])
    list.append(a)
list
# Out:
# ['논현동',
#  '개포동',
#  '자곡동',
#  '세곡동',
#  '자곡동',
#  '개포동',
#  '삼성동',
#  '일원동',
#  '일원동',
#  '일원동',
#  '대치동',
#  '개포동',
#  '수서동',
#  '개포동',
#  '압구정동',
#  '대치동',
#  '논현동',
#  '삼성동',
#  '도곡동',
#  '대치동',
#  '신사동',
#  '대치동',
#  '청담동',
#  '삼성동',
#  '수서동',
#  '일원동',
#  '청담동',
#  '역삼동',
#  '개포동',
#  '개포동',
#  '상일동',
#  '천호동',
#  '상일동',
#  '고덕동',
#  '강일동',
#  '성내동',
#  '상일동',
#  '천호동',
#  '명일동',
#  '상일동',
#  '암사동',
#  '암사동',
#  '암사동',
#  '명일동',
#  '길동',
#  '상일동',
#  '길동',
#  '천호동',
#  '명일동',
#  '고덕동',
#  '강일동',
#  '둔촌동',
#  '천호동',
#  '고덕동',
#  '고덕동',
#  '둔촌동',
#  '상일동',
#  '길동',
#  '미아동',
#  '미아동',
#  '번동',
#  '번동',
#  '수유동',
#  '수유동',
#  '미아동',
#  '미아동',
#  '수유동',
#  '미아동',
#  '번동',
#  '번동',
#  '미아동',
#  '미아동',
#  '수유동',
#  '수유동',
#  '미아동',
#  '미아동',
#  '수유동',
#  '마곡동',
#  '등촌동',
#  '가양동',
#  '마곡동',
#  '등촌동',
#  '화곡동',
#  '마곡동',
#  '화곡동',
#  '내발산동',
#  '화곡동',
#  '내발산동',
#  '등촌동',
#  '방화동',
#  '화곡동',
#  '가양동',
#  '염창동',
#  '공항동',
#  '등촌동',
#  '내발산동',
#  '공항동',
#  '등촌동',
#  '화곡동',
#  '방화동',
# ...

# %%
free_places_dup['동명']= list
free_places_dup.head()
# Out:
# <ipython-input-329-51d838eff5bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   free_places_dup['동명']= list
#                 place type                         address 시군구명   동명
# 20   서울학동초등학교 어린이놀이시설   학교      서울특별시 강남구 선릉로115길 42 (논현동)  강남구  논현동
# 56            한국외국인학교   학교  서울특별시 강남구 개포로 408 (개포동)한국외국인학교  강남구  개포동
# 73     서울율현초등학교운동장놀이터   학교      서울특별시 강남구 밤고개로21길 15 (자곡동)  강남구  자곡동
# 134          서울세명초등학교   학교          서울특별시 강남구 자곡로 55 (세곡동)  강남구  세곡동
# 140          서울자곡초등학교   학교         서울특별시 강남구 자곡로 150 (자곡동)  강남구  자곡동

# %%
names = free_places_dup['동명']

words= []
for word in names : 
    if word == '상왕십리':
        a= word.replace('상왕십리','상왕십리동')
        words.append(a)
    elif word =='하왕십리':
        b= word.replace('하왕십리','하왕십리동')
        words.append(b)
        
    else :
        words.append(word)
    
words
# Out:
# ['논현동',
#  '개포동',
#  '자곡동',
#  '세곡동',
#  '자곡동',
#  '개포동',
#  '삼성동',
#  '일원동',
#  '일원동',
#  '일원동',
#  '대치동',
#  '개포동',
#  '수서동',
#  '개포동',
#  '압구정동',
#  '대치동',
#  '논현동',
#  '삼성동',
#  '도곡동',
#  '대치동',
#  '신사동',
#  '대치동',
#  '청담동',
#  '삼성동',
#  '수서동',
#  '일원동',
#  '청담동',
#  '역삼동',
#  '개포동',
#  '개포동',
#  '상일동',
#  '천호동',
#  '상일동',
#  '고덕동',
#  '강일동',
#  '성내동',
#  '상일동',
#  '천호동',
#  '명일동',
#  '상일동',
#  '암사동',
#  '암사동',
#  '암사동',
#  '명일동',
#  '길동',
#  '상일동',
#  '길동',
#  '천호동',
#  '명일동',
#  '고덕동',
#  '강일동',
#  '둔촌동',
#  '천호동',
#  '고덕동',
#  '고덕동',
#  '둔촌동',
#  '상일동',
#  '길동',
#  '미아동',
#  '미아동',
#  '번동',
#  '번동',
#  '수유동',
#  '수유동',
#  '미아동',
#  '미아동',
#  '수유동',
#  '미아동',
#  '번동',
#  '번동',
#  '미아동',
#  '미아동',
#  '수유동',
#  '수유동',
#  '미아동',
#  '미아동',
#  '수유동',
#  '마곡동',
#  '등촌동',
#  '가양동',
#  '마곡동',
#  '등촌동',
#  '화곡동',
#  '마곡동',
#  '화곡동',
#  '내발산동',
#  '화곡동',
#  '내발산동',
#  '등촌동',
#  '방화동',
#  '화곡동',
#  '가양동',
#  '염창동',
#  '공항동',
#  '등촌동',
#  '내발산동',
#  '공항동',
#  '등촌동',
#  '화곡동',
#  '방화동',
# ...

# %%
free_places_dup['동명'] = words
free_places_dup.head()
# Out:
# <ipython-input-333-b55f7dceea64>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   free_places_dup['동명'] = words
#                 place type                         address 시군구명   동명
# 20   서울학동초등학교 어린이놀이시설   학교      서울특별시 강남구 선릉로115길 42 (논현동)  강남구  논현동
# 56            한국외국인학교   학교  서울특별시 강남구 개포로 408 (개포동)한국외국인학교  강남구  개포동
# 73     서울율현초등학교운동장놀이터   학교      서울특별시 강남구 밤고개로21길 15 (자곡동)  강남구  자곡동
# 134          서울세명초등학교   학교          서울특별시 강남구 자곡로 55 (세곡동)  강남구  세곡동
# 140          서울자곡초등학교   학교         서울특별시 강남구 자곡로 150 (자곡동)  강남구  자곡동

# %%
free_places_dup[free_places_dup['동명'] == '청파동2가']
# Out:
# Empty DataFrame
# Columns: [place, type, address, 시군구명, 동명]
# Index: []

# %%
free_places_dup.to_csv('D:/Ella/project/seoul_어린이놀이터_freezone.csv', index =False)

# %%
for place in pay_zones : 
    a = df[df['type'] == place]
    pay_places.append(a)
    
    #중복값 제거
    pay_places = pay_places.drop_duplicates()
    
pay_places.info()

# pay_places.to_excel('D:/Ella/project/pay_places.xlsx')
# kid_add.to_excel('D:/Ella/project/seoul_놀이터(동별)_final.xlsx')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 304 entries, 44 to 8896
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   place    304 non-null    object
#  1   type     304 non-null    object
#  2   address  304 non-null    object
#  3   시군구명     304 non-null    object
#  4   동명       304 non-null    object
# dtypes: object(5)
# memory usage: 14.2+ KB

# %%
pay_places.to_csv('D:/Ella/project/seoul_어린이놀이터_payzone_final.csv', index =False)
